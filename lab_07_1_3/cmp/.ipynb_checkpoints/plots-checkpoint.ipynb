# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
direct_sorted = pd.read_csv('sorted.csv')
back_sorted = pd.read_csv('back_sorted.csv')
not_sorted = pd.read_csv('not_sorted.csv')

# %%
sns.set_style("darkgrid")

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='mysort', data=back_sorted)

plt.title('mysort')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['direct sorted array', 'not sorted array', 'back sorted array'])

plt.show()

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='qsort', data=direct_sorted)

plt.title('direct sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
direct_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.000  0.002
# 1  10000   0.000  0.003
# 2  15000   0.000  0.004
# 3  20000   0.000  0.001
# 4  25000   0.000  0.009
# 5  30000   0.001  0.003
# 6  35000   0.000  0.000
# 7  40000   0.000  0.009
# 8  45000   0.000  0.000
# 9  50000   0.007  0.001

# %%
sns.lineplot(x='n', y='mysort', data=back_sorted)
sns.lineplot(x='n', y='qsort', data=back_sorted)

plt.title('back sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
back_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.420  0.006
# 1  10000   2.259  0.000
# 2  15000   4.194  0.003
# 3  20000   8.233  0.000
# 4  25000  14.566  0.008
# 5  30000  21.953  0.010
# 6  35000  29.172  0.012
# 7  40000  38.863  0.000
# 8  45000  45.969  0.010
# 9  50000  68.658  0.000

# %%
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='qsort', data=not_sorted)

plt.title('not sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
not_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.339  0.002
# 1  10000   1.281  0.004
# 2  15000   2.860  0.002
# 3  20000   5.501  0.007
# 4  25000   7.796  0.000
# 5  30000  10.787  0.000
# 6  35000  14.659  0.014
# 7  40000  19.105  0.006
# 8  45000  25.275  0.008
# 9  50000  31.809  0.028
