# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
direct_sorted = pd.read_csv('sorted.csv')
back_sorted = pd.read_csv('back_sorted.csv')
not_sorted = pd.read_csv('not_sorted.csv')

# %%
sns.set_style("darkgrid")

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='mysort', data=back_sorted)

plt.title('mysort')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['direct sorted array', 'not sorted array', 'back sorted array'])

plt.show()

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='qsort', data=direct_sorted)

plt.title('direct sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
direct_sorted
# Out:
#        n    mysort     qsort
# 0   5000  0.000000  0.001667
# 1  10000  0.000333  0.002667
# 2  15000  0.000333  0.004333
# 3  20000  0.000000  0.010333
# 4  25000  0.000667  0.008333
# 5  30000  0.001667  0.007667
# 6  35000  0.001333  0.012000
# 7  40000  0.001667  0.010333
# 8  45000  0.001333  0.011333
# 9  50000  0.001333  0.014333

# %%
sns.lineplot(x='n', y='mysort', data=back_sorted)
sns.lineplot(x='n', y='qsort', data=back_sorted)

plt.title('back sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
back_sorted
# Out:
#        n     mysort     qsort
# 0   5000   0.567333  0.000000
# 1  10000   1.801000  0.000333
# 2  15000   4.200333  0.003333
# 3  20000   6.643000  0.000333
# 4  25000  13.624667  0.003333
# 5  30000  20.634000  0.000000
# 6  35000  23.897667  0.003667
# 7  40000  26.079333  0.002000
# 8  45000  25.963333  0.003000
# 9  50000  34.113000  0.003333

# %%
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='qsort', data=not_sorted)

plt.title('not sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
not_sorted
# Out:
#        n     mysort     qsort
# 0   5000   0.169667  0.000000
# 1  10000   0.675333  0.000667
# 2  15000   1.471667  0.001333
# 3  20000   2.599667  0.001667
# 4  25000   4.169667  0.002000
# 5  30000   5.748667  0.002333
# 6  35000  10.022000  0.004333
# 7  40000  18.238333  0.006333
# 8  45000  22.678667  0.008667
# 9  50000  27.242000  0.007667
