# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
direct_sorted = pd.read_csv('sorted.csv')
back_sorted = pd.read_csv('back_sorted.csv')
not_sorted = pd.read_csv('not_sorted.csv')

# %%
sns.set_style("darkgrid")

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='mysort', data=back_sorted)

plt.title('mysort')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['direct sorted array', 'not sorted array', 'back sorted array'])

plt.show()

# %%
sns.lineplot(x='n', y='mysort', data=direct_sorted)
sns.lineplot(x='n', y='qsort', data=direct_sorted)

plt.title('direct sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
direct_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.000  0.001
# 1  10000   0.001  0.002
# 2  15000   0.000  0.001
# 3  20000   0.000  0.008
# 4  25000   0.000  0.000
# 5  30000   0.000  0.006
# 6  35000   0.000  0.000
# 7  40000   0.006  0.004
# 8  45000   0.000  0.008
# 9  50000   0.000  0.000

# %%
sns.lineplot(x='n', y='mysort', data=back_sorted)
sns.lineplot(x='n', y='qsort', data=back_sorted)

plt.title('back sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
back_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.635  0.001
# 1  10000   1.896  0.011
# 2  15000   4.607  0.000
# 3  20000   8.098  0.001
# 4  25000  12.825  0.000
# 5  30000  20.783  0.000
# 6  35000  27.430  0.007
# 7  40000  38.517  0.006
# 8  45000  46.277  0.006
# 9  50000  58.111  0.004

# %%
sns.lineplot(x='n', y='mysort', data=not_sorted)
sns.lineplot(x='n', y='qsort', data=not_sorted)

plt.title('not sorted array')
plt.xlabel('number of elements')
plt.ylabel('time')

plt.legend(labels=['mysort', 'qsort'])

plt.show()
not_sorted
# Out:
#        n  mysort  qsort
# 0   5000   0.346  0.000
# 1  10000   1.029  0.000
# 2  15000   2.246  0.000
# 3  20000   4.554  0.002
# 4  25000   7.172  0.000
# 5  30000  10.033  0.000
# 6  35000  13.699  0.015
# 7  40000  19.210  0.000
# 8  45000  22.546  0.000
# 9  50000  28.886  0.010
